# %% [markdown]
# ## Importing required libraries

# %%
import datetime

import numpy as np
import pandas as pd

# import matplotlib.pyplot as plt
# import seaborn as sns
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score

# %% [markdown]
# ## Reading CSV file

# %%
a=pd.read_csv("car_price.csv")
a.head()
# Out:
#    Unnamed: 0                                car_name car_prices_in_rupee  \
# 0           0  Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh
# 1           1            Renault Duster RXZ Turbo CVT          12.83 Lakh
# 2           2                      Toyota Camry 2.5 G          16.40 Lakh
# 3           3                       Honda Jazz VX CVT           7.77 Lakh
# 4           4        Volkswagen Polo 1.2 MPI Highline           5.15 Lakh
#
#    kms_driven fuel_type transmission  ownership  manufacture   engine    Seats
# 0  86,226 kms    Diesel       Manual  1st Owner         2017  1956 cc  5 Seats
# 1  13,248 kms    Petrol    Automatic  1st Owner         2021  1330 cc  5 Seats
# 2  60,343 kms    Petrol    Automatic  1st Owner         2016  2494 cc  5 Seats
# 3  26,696 kms    Petrol    Automatic  1st Owner         2018  1199 cc  5 Seats
# 4  69,414 kms    Petrol       Manual  1st Owner         2016  1199 cc  5 Seats

# %% [markdown]
# ## Performing EDA (Exploratory Data Analysis)

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5512 entries, 0 to 5511
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           5512 non-null   int64
#  1   car_name             5512 non-null   object
#  2   car_prices_in_rupee  5512 non-null   object
#  3   kms_driven           5512 non-null   object
#  4   fuel_type            5512 non-null   object
#  5   transmission         5512 non-null   object
#  6   ownership            5512 non-null   object
#  7   manufacture          5512 non-null   int64
#  8   engine               5512 non-null   object
#  9   Seats                5512 non-null   object
# dtypes: int64(2), object(8)
# memory usage: 430.8+ KB

# %%
a.describe()
# Out:
#         Unnamed: 0  manufacture
# count  5512.000000  5512.000000
# mean   2755.500000  2015.455552
# std    1591.321673     3.927974
# min       0.000000  1995.000000
# 25%    1377.750000  2013.000000
# 50%    2755.500000  2016.000000
# 75%    4133.250000  2018.000000
# max    5511.000000  2022.000000

# %%
a[a.isna()].count()
# Out:
# Unnamed: 0             0
# car_name               0
# car_prices_in_rupee    0
# kms_driven             0
# fuel_type              0
# transmission           0
# ownership              0
# manufacture            0
# engine                 0
# Seats                  0
# dtype: int64

# %% [markdown]
# ## Cleaning Dataset:
# since Unnamed: 0 column is not required we will remove it

# %%
a=a.drop(columns='Unnamed: 0',axis=1)

# %%
a
# Out:
#                                     car_name car_prices_in_rupee  kms_driven  \
# 0     Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh  86,226 kms
# 1               Renault Duster RXZ Turbo CVT          12.83 Lakh  13,248 kms
# 2                         Toyota Camry 2.5 G          16.40 Lakh  60,343 kms
# 3                          Honda Jazz VX CVT           7.77 Lakh  26,696 kms
# 4           Volkswagen Polo 1.2 MPI Highline           5.15 Lakh  69,414 kms
# ...                                      ...                 ...         ...
# 5507                 BMW X1 sDrive 20d xLine          28.90 Lakh  45,000 kms
# 5508                   BMW M Series M4 Coupe          64.90 Lakh  29,000 kms
# 5509              Jaguar XF 2.2 Litre Luxury          13.75 Lakh  90,000 kms
# 5510                      BMW 7 Series 730Ld          29.90 Lakh  79,000 kms
# 5511               BMW 5 Series 520d M Sport          31.90 Lakh  42,000 kms
#
#      fuel_type transmission  ownership  manufacture   engine    Seats
# 0       Diesel       Manual  1st Owner         2017  1956 cc  5 Seats
# 1       Petrol    Automatic  1st Owner         2021  1330 cc  5 Seats
# 2       Petrol    Automatic  1st Owner         2016  2494 cc  5 Seats
# 3       Petrol    Automatic  1st Owner         2018  1199 cc  5 Seats
# 4       Petrol       Manual  1st Owner         2016  1199 cc  5 Seats
# ...        ...          ...        ...          ...      ...      ...
# 5507    Diesel    Automatic  1st Owner         2018  2995 cc  7 Seats
# 5508    Petrol    Automatic  2nd Owner         2015  1968 cc  5 Seats
# 5509    Diesel    Automatic  2nd Owner         2013  2755 cc  5 Seats
# 5510    Diesel    Automatic  3rd Owner         2015  2967 cc  6 Seats
# 5511    Diesel    Automatic  2nd Owner         2017  1991 cc  5 Seats
#
# [5512 rows x 9 columns]

# %% [markdown]
# ## Creating new coulmn named Currency

# %%
a.loc[a['car_prices_in_rupee'].str.contains('Lakh'), 'Currency'] = 'Lakh'
a.loc[a['car_prices_in_rupee'].str.contains('Crore'), 'Currency'] = 'Crore'
a
# Out:
#                                     car_name car_prices_in_rupee  kms_driven  \
# 0     Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh  86,226 kms
# 1               Renault Duster RXZ Turbo CVT          12.83 Lakh  13,248 kms
# 2                         Toyota Camry 2.5 G          16.40 Lakh  60,343 kms
# 3                          Honda Jazz VX CVT           7.77 Lakh  26,696 kms
# 4           Volkswagen Polo 1.2 MPI Highline           5.15 Lakh  69,414 kms
# ...                                      ...                 ...         ...
# 5507                 BMW X1 sDrive 20d xLine          28.90 Lakh  45,000 kms
# 5508                   BMW M Series M4 Coupe          64.90 Lakh  29,000 kms
# 5509              Jaguar XF 2.2 Litre Luxury          13.75 Lakh  90,000 kms
# 5510                      BMW 7 Series 730Ld          29.90 Lakh  79,000 kms
# 5511               BMW 5 Series 520d M Sport          31.90 Lakh  42,000 kms
#
#      fuel_type transmission  ownership  manufacture   engine    Seats Currency
# 0       Diesel       Manual  1st Owner         2017  1956 cc  5 Seats     Lakh
# 1       Petrol    Automatic  1st Owner         2021  1330 cc  5 Seats     Lakh
# 2       Petrol    Automatic  1st Owner         2016  2494 cc  5 Seats     Lakh
# 3       Petrol    Automatic  1st Owner         2018  1199 cc  5 Seats     Lakh
# 4       Petrol       Manual  1st Owner         2016  1199 cc  5 Seats     Lakh
# ...        ...          ...        ...          ...      ...      ...      ...
# 5507    Diesel    Automatic  1st Owner         2018  2995 cc  7 Seats     Lakh
# 5508    Petrol    Automatic  2nd Owner         2015  1968 cc  5 Seats     Lakh
# 5509    Diesel    Automatic  2nd Owner         2013  2755 cc  5 Seats     Lakh
# 5510    Diesel    Automatic  3rd Owner         2015  2967 cc  6 Seats     Lakh
# 5511    Diesel    Automatic  2nd Owner         2017  1991 cc  5 Seats     Lakh
#
# [5512 rows x 10 columns]

# %% [markdown]
# ## Dropping all NULL values using dropna() method
# Since our model cannot compute null values

# %%
a=a.dropna()
a
# Out:
#                                     car_name car_prices_in_rupee  kms_driven  \
# 0     Jeep Compass 2.0 Longitude Option BSIV          10.03 Lakh  86,226 kms
# 1               Renault Duster RXZ Turbo CVT          12.83 Lakh  13,248 kms
# 2                         Toyota Camry 2.5 G          16.40 Lakh  60,343 kms
# 3                          Honda Jazz VX CVT           7.77 Lakh  26,696 kms
# 4           Volkswagen Polo 1.2 MPI Highline           5.15 Lakh  69,414 kms
# ...                                      ...                 ...         ...
# 5507                 BMW X1 sDrive 20d xLine          28.90 Lakh  45,000 kms
# 5508                   BMW M Series M4 Coupe          64.90 Lakh  29,000 kms
# 5509              Jaguar XF 2.2 Litre Luxury          13.75 Lakh  90,000 kms
# 5510                      BMW 7 Series 730Ld          29.90 Lakh  79,000 kms
# 5511               BMW 5 Series 520d M Sport          31.90 Lakh  42,000 kms
#
#      fuel_type transmission  ownership  manufacture   engine    Seats Currency
# 0       Diesel       Manual  1st Owner         2017  1956 cc  5 Seats     Lakh
# 1       Petrol    Automatic  1st Owner         2021  1330 cc  5 Seats     Lakh
# 2       Petrol    Automatic  1st Owner         2016  2494 cc  5 Seats     Lakh
# 3       Petrol    Automatic  1st Owner         2018  1199 cc  5 Seats     Lakh
# 4       Petrol       Manual  1st Owner         2016  1199 cc  5 Seats     Lakh
# ...        ...          ...        ...          ...      ...      ...      ...
# 5507    Diesel    Automatic  1st Owner         2018  2995 cc  7 Seats     Lakh
# 5508    Petrol    Automatic  2nd Owner         2015  1968 cc  5 Seats     Lakh
# 5509    Diesel    Automatic  2nd Owner         2013  2755 cc  5 Seats     Lakh
# 5510    Diesel    Automatic  3rd Owner         2015  2967 cc  6 Seats     Lakh
# 5511    Diesel    Automatic  2nd Owner         2017  1991 cc  5 Seats     Lakh
#
# [5389 rows x 10 columns]

# %% [markdown]
# ## Cleaning Data:
# Removing Strings attached with numbers and removing commas

# %%
a['kms_driven']=a['kms_driven'].str.replace(' kms','')
a['car_prices_in_rupee']=a['car_prices_in_rupee'].str.replace(' Lakh','')
a['kms_driven']=a['kms_driven'].str.replace(',','')
a['Seats']=a['Seats'].str.replace(' Seats','')
a['engine']=a['engine'].str.replace(' cc','')
a['car_prices_in_rupee']=a['car_prices_in_rupee'].str.replace(' Crore','')
# Out:
# <ipython-input-10-abcec9b3dfda>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['kms_driven']=a['kms_driven'].str.replace(' kms','')
# <ipython-input-10-abcec9b3dfda>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['car_prices_in_rupee']=a['car_prices_in_rupee'].str.replace(' Lakh','')
# <ipython-input-10-abcec9b3dfda>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['kms_driven']=a['kms_driven'].str.replace(',','')
# <ipython-input-10-abcec9b3dfda>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['Seats']=a['Seats'].str.replace(' Seats','')
# <ipython-input-10-abcec9b3dfda>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['engine']=a['engine'].str.replace(' cc','')
# <ipython-input-10-abcec9b3dfda>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['car_prices_in_rupee']=a['car_prices_in_rupee'].str.replace(' Crore','')

# %%
a
# Out:
#                                     car_name car_prices_in_rupee kms_driven  \
# 0     Jeep Compass 2.0 Longitude Option BSIV               10.03      86226
# 1               Renault Duster RXZ Turbo CVT               12.83      13248
# 2                         Toyota Camry 2.5 G               16.40      60343
# 3                          Honda Jazz VX CVT                7.77      26696
# 4           Volkswagen Polo 1.2 MPI Highline                5.15      69414
# ...                                      ...                 ...        ...
# 5507                 BMW X1 sDrive 20d xLine               28.90      45000
# 5508                   BMW M Series M4 Coupe               64.90      29000
# 5509              Jaguar XF 2.2 Litre Luxury               13.75      90000
# 5510                      BMW 7 Series 730Ld               29.90      79000
# 5511               BMW 5 Series 520d M Sport               31.90      42000
#
#      fuel_type transmission  ownership  manufacture engine Seats Currency
# 0       Diesel       Manual  1st Owner         2017   1956     5     Lakh
# 1       Petrol    Automatic  1st Owner         2021   1330     5     Lakh
# 2       Petrol    Automatic  1st Owner         2016   2494     5     Lakh
# 3       Petrol    Automatic  1st Owner         2018   1199     5     Lakh
# 4       Petrol       Manual  1st Owner         2016   1199     5     Lakh
# ...        ...          ...        ...          ...    ...   ...      ...
# 5507    Diesel    Automatic  1st Owner         2018   2995     7     Lakh
# 5508    Petrol    Automatic  2nd Owner         2015   1968     5     Lakh
# 5509    Diesel    Automatic  2nd Owner         2013   2755     5     Lakh
# 5510    Diesel    Automatic  3rd Owner         2015   2967     6     Lakh
# 5511    Diesel    Automatic  2nd Owner         2017   1991     5     Lakh
#
# [5389 rows x 10 columns]

# %% [markdown]
# ## Converting Strings to int and float type for computing

# %%
a['car_prices_in_rupee']=a['car_prices_in_rupee'].astype('float')
a['kms_driven']=a['kms_driven'].astype('int')
a['Seats']=a['Seats'].astype('int')
a['engine']=a['engine'].astype('int')
# Out:
# <ipython-input-12-085428d5fc2a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['car_prices_in_rupee']=a['car_prices_in_rupee'].astype('float')
# <ipython-input-12-085428d5fc2a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['kms_driven']=a['kms_driven'].astype('int')
# <ipython-input-12-085428d5fc2a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['Seats']=a['Seats'].astype('int')
# <ipython-input-12-085428d5fc2a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['engine']=a['engine'].astype('int')

# %%
a
# Out:
#                                     car_name  car_prices_in_rupee  kms_driven  \
# 0     Jeep Compass 2.0 Longitude Option BSIV                10.03       86226
# 1               Renault Duster RXZ Turbo CVT                12.83       13248
# 2                         Toyota Camry 2.5 G                16.40       60343
# 3                          Honda Jazz VX CVT                 7.77       26696
# 4           Volkswagen Polo 1.2 MPI Highline                 5.15       69414
# ...                                      ...                  ...         ...
# 5507                 BMW X1 sDrive 20d xLine                28.90       45000
# 5508                   BMW M Series M4 Coupe                64.90       29000
# 5509              Jaguar XF 2.2 Litre Luxury                13.75       90000
# 5510                      BMW 7 Series 730Ld                29.90       79000
# 5511               BMW 5 Series 520d M Sport                31.90       42000
#
#      fuel_type transmission  ownership  manufacture  engine  Seats Currency
# 0       Diesel       Manual  1st Owner         2017    1956      5     Lakh
# 1       Petrol    Automatic  1st Owner         2021    1330      5     Lakh
# 2       Petrol    Automatic  1st Owner         2016    2494      5     Lakh
# 3       Petrol    Automatic  1st Owner         2018    1199      5     Lakh
# 4       Petrol       Manual  1st Owner         2016    1199      5     Lakh
# ...        ...          ...        ...          ...     ...    ...      ...
# 5507    Diesel    Automatic  1st Owner         2018    2995      7     Lakh
# 5508    Petrol    Automatic  2nd Owner         2015    1968      5     Lakh
# 5509    Diesel    Automatic  2nd Owner         2013    2755      5     Lakh
# 5510    Diesel    Automatic  3rd Owner         2015    2967      6     Lakh
# 5511    Diesel    Automatic  2nd Owner         2017    1991      5     Lakh
#
# [5389 rows x 10 columns]

# %%
a['car_prices_in_rupee']=np.where(a['Currency'] == 'Crore',
                                           a['car_prices_in_rupee'] * 100,
                                           a['car_prices_in_rupee'])
# Out:
# <ipython-input-14-3f74a1502c98>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['car_prices_in_rupee']=np.where(a['Currency'] == 'Crore',

# %%
a
# Out:
#                                     car_name  car_prices_in_rupee  kms_driven  \
# 0     Jeep Compass 2.0 Longitude Option BSIV                10.03       86226
# 1               Renault Duster RXZ Turbo CVT                12.83       13248
# 2                         Toyota Camry 2.5 G                16.40       60343
# 3                          Honda Jazz VX CVT                 7.77       26696
# 4           Volkswagen Polo 1.2 MPI Highline                 5.15       69414
# ...                                      ...                  ...         ...
# 5507                 BMW X1 sDrive 20d xLine                28.90       45000
# 5508                   BMW M Series M4 Coupe                64.90       29000
# 5509              Jaguar XF 2.2 Litre Luxury                13.75       90000
# 5510                      BMW 7 Series 730Ld                29.90       79000
# 5511               BMW 5 Series 520d M Sport                31.90       42000
#
#      fuel_type transmission  ownership  manufacture  engine  Seats Currency
# 0       Diesel       Manual  1st Owner         2017    1956      5     Lakh
# 1       Petrol    Automatic  1st Owner         2021    1330      5     Lakh
# 2       Petrol    Automatic  1st Owner         2016    2494      5     Lakh
# 3       Petrol    Automatic  1st Owner         2018    1199      5     Lakh
# 4       Petrol       Manual  1st Owner         2016    1199      5     Lakh
# ...        ...          ...        ...          ...     ...    ...      ...
# 5507    Diesel    Automatic  1st Owner         2018    2995      7     Lakh
# 5508    Petrol    Automatic  2nd Owner         2015    1968      5     Lakh
# 5509    Diesel    Automatic  2nd Owner         2013    2755      5     Lakh
# 5510    Diesel    Automatic  3rd Owner         2015    2967      6     Lakh
# 5511    Diesel    Automatic  2nd Owner         2017    1991      5     Lakh
#
# [5389 rows x 10 columns]

# %%
a['car_prices_in_rupee']=a['car_prices_in_rupee']*100000
a
# Out:
# <ipython-input-16-f0eb10af5d47>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['car_prices_in_rupee']=a['car_prices_in_rupee']*100000
#                                     car_name  car_prices_in_rupee  kms_driven  \
# 0     Jeep Compass 2.0 Longitude Option BSIV            1003000.0       86226
# 1               Renault Duster RXZ Turbo CVT            1283000.0       13248
# 2                         Toyota Camry 2.5 G            1640000.0       60343
# 3                          Honda Jazz VX CVT             777000.0       26696
# 4           Volkswagen Polo 1.2 MPI Highline             515000.0       69414
# ...                                      ...                  ...         ...
# 5507                 BMW X1 sDrive 20d xLine            2890000.0       45000
# 5508                   BMW M Series M4 Coupe            6490000.0       29000
# 5509              Jaguar XF 2.2 Litre Luxury            1375000.0       90000
# 5510                      BMW 7 Series 730Ld            2990000.0       79000
# 5511               BMW 5 Series 520d M Sport            3190000.0       42000
#
#      fuel_type transmission  ownership  manufacture  engine  Seats Currency
# 0       Diesel       Manual  1st Owner         2017    1956      5     Lakh
# 1       Petrol    Automatic  1st Owner         2021    1330      5     Lakh
# 2       Petrol    Automatic  1st Owner         2016    2494      5     Lakh
# 3       Petrol    Automatic  1st Owner         2018    1199      5     Lakh
# 4       Petrol       Manual  1st Owner         2016    1199      5     Lakh
# ...        ...          ...        ...          ...     ...    ...      ...
# 5507    Diesel    Automatic  1st Owner         2018    2995      7     Lakh
# 5508    Petrol    Automatic  2nd Owner         2015    1968      5     Lakh
# 5509    Diesel    Automatic  2nd Owner         2013    2755      5     Lakh
# 5510    Diesel    Automatic  3rd Owner         2015    2967      6     Lakh
# 5511    Diesel    Automatic  2nd Owner         2017    1991      5     Lakh
#
# [5389 rows x 10 columns]

# %%
train=a.copy()

# %%
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn import metrics
from sklearn.metrics import r2_score

# %%
X= train.drop(columns=['car_prices_in_rupee','car_name','ownership', 'fuel_type'] ,axis=1)
Y= train['car_prices_in_rupee']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.15, random_state = 100)

# %%
# make_train = X_train["car_name"].str.split(" ", expand = True)
# make_test = X_test["car_name"].str.split(" ", expand = True)
# make_train

# %%
# X_train["Manufacturer"] = make_train[0]
# X_test["Manufacturer"] = make_test[0]
# X_train

# %%
X_train = pd.get_dummies(X_train,
                         columns = ['Currency' ,"transmission"],
                         drop_first = True)

X_test = pd.get_dummies(X_test,
                         columns = ['Currency', "transmission"],
                         drop_first = True)
# X_train.drop("car_name",axis=1,inplace=True)
# X_test.drop("car_name",axis=1,inplace=True)

# %%
model=LinearRegression()
model.fit(X_train,y_train)
ypred=model.predict(X_test)

# %%
X_test
# Out:
#       kms_driven  manufacture  engine  Seats  Currency_Lakh  \
# 1025       32272         2020    1086      5              1
# 1786       36000         2018    1498      5              1
# 3986      170290         2016    1248      5              1
# 1608       40000         2019    1968      5              1
# 296       105053         2013    1248      5              1
# ...          ...          ...     ...    ...            ...
# 1289       30000         2020    1451      5              1
# 3799       55077         2009    1497      5              1
# 537        50152         2011    1461      5              1
# 3861       67000         2013     999      5              1
# 1861       45000         2019    1497      7              1
#
#       transmission_Manual
# 1025                    0
# 1786                    1
# 3986                    0
# 1608                    1
# 296                     1
# ...                   ...
# 1289                    0
# 3799                    1
# 537                     1
# 3861                    1
# 1861                    0
#
# [809 rows x 6 columns]

# %%
ypred
# Out:
# array([ 2.61909079e+06,  8.52166158e+05,  2.08140008e+06,  1.02367814e+06,
#         2.39258061e+05,  1.18325918e+06,  4.32081674e+05,  1.19851883e+06,
#         6.03635292e+05,  6.01560037e+05,  7.02135944e+05,  8.27272757e+05,
#         2.54247334e+06,  1.09646946e+06,  2.75017091e+06,  2.07535147e+06,
#         9.98446779e+05, -7.27144696e+04,  6.72975430e+05,  6.54742640e+05,
#         8.37788281e+05,  1.03166187e+06,  6.24358208e+05,  1.34825109e+05,
#         1.06949677e+06,  2.54603815e+05,  7.93217190e+05,  5.54691272e+05,
#         2.87559158e+04,  3.82989126e+05,  3.53866074e+05,  2.85964783e+06,
#         9.93743756e+05,  8.91264065e+05,  2.38392964e+06,  5.29765218e+05,
#         2.49390043e+06,  2.78042466e+06,  1.11923566e+06,  8.99452952e+05,
#        -2.16665813e+05, -2.85386875e+05,  2.88872303e+06,  8.29212568e+05,
#         9.80581030e+05,  2.78695698e+06,  2.44790718e+06,  8.68877207e+05,
#         4.48880006e+05,  4.01876323e+05,  7.18446206e+05,  2.18383471e+06,
#         3.18176259e+04, -5.45069011e+04,  9.38170457e+05,  6.96474390e+05,
#        -4.34168648e+04,  4.18896420e+05, -2.55147445e+05,  9.04383131e+05,
#         5.66649741e+05,  2.59066011e+06,  1.86698946e+06,  1.09104460e+05,
#         6.84855108e+05,  2.24981775e+06,  5.10020097e+05,  2.54620157e+05,
#         1.25810945e+06,  2.11702503e+06,  1.52332212e+07,  2.91946970e+05,
#         2.61486802e+06,  7.22445284e+05,  2.79805745e+05,  2.93329881e+05,
#         9.31325620e+05,  4.13577694e+05,  7.57724952e+05,  2.29062669e+05,
#         2.93970224e+05,  2.98983413e+06,  2.33603323e+06,  2.28447767e+06,
#         5.59985215e+05,  2.79460116e+05,  2.75888273e+06,  6.76851463e+05,
#         7.20483618e+05,  3.86248144e+05,  2.99900944e+05,  5.59083346e+05,
#         4.90837354e+05,  1.17960107e+05,  7.88673926e+05,  1.79508273e+05,
#        -2.13521025e+05,  8.09418111e+05,  2.66455496e+06,  4.28518254e+05,
#         7.83465232e+05,  2.07106546e+06,  2.36897491e+05,  4.42278283e+05,
#         3.67057132e+05,  7.40403219e+05,  3.38277674e+05,  5.51219830e+05,
#         6.61424641e+05,  4.82830034e+05,  5.72802589e+05, -1.87988167e+05,
#         1.61905624e+06,  4.98980376e+05,  2.30997880e+06,  9.18607878e+05,
#         1.93804540e+06,  5.36979745e+05,  2.09834223e+06,  7.25618096e+05,
#         2.03630220e+06, -1.61291539e+05,  4.73426875e+05,  2.41192326e+06,
#         3.63214751e+05,  1.20735992e+06,  5.74765660e+05,  1.00150955e+06,
#         2.89791167e+05,  2.47145976e+06,  2.98104204e+05,  1.04604174e+06,
#         6.30918947e+05, -1.03377342e+05,  8.16257296e+05,  6.62195405e+05,
#         8.43315425e+05,  8.64534408e+05,  5.01550307e+05,  2.24269805e+06,
#         9.90716482e+04,  2.92860813e+06,  1.01070986e+06,  1.29361166e+06,
#        -2.44833497e+05, -3.71140149e+05,  2.19812051e+06,  2.69294410e+06,
#         2.13919314e+06,  4.35165098e+05,  6.72676826e+05,  2.62497251e+06,
#         1.04342721e+06,  7.20406954e+05,  7.93562820e+05,  3.51819376e+05,
#         2.27230199e+06,  1.01786807e+06,  5.68745541e+05,  2.46610577e+05,
#         3.90385014e+05,  2.59372645e+06,  1.16181933e+06,  2.40374680e+06,
#         1.49525856e+07,  1.05390043e+06,  2.02001538e+06,  8.77249236e+04,
#         4.25848631e+05,  3.20637977e+05,  6.64522786e+05,  2.60813607e+05,
#         2.16958466e+05, -1.64224660e+05,  2.20360837e+06,  2.39322540e+06,
#         4.74525484e+05,  6.03900476e+05,  6.16177935e+05,  6.84055527e+05,
#         6.19572492e+05,  4.25736743e+05,  5.35816815e+05,  6.64040906e+05,
#        -6.38800143e+04,  2.42570305e+06,  2.56218513e+05,  1.05540873e+06,
#         4.08179721e+05,  4.97397978e+05,  7.75281074e+05,  3.01875945e+06,
#        -3.52237937e+05,  2.54910441e+06,  8.89278345e+05, -1.07613571e+04,
#         2.68518536e+06, -3.37480399e+04,  1.57772586e+05,  2.46760266e+05,
#         2.55241009e+06])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,ypred)
# Out:
# 0.7332676982532722

# %%
c=int(input("Enter the Kilometer_driven: "))
# Out:
# Enter the Kilometer_driven: 200000

# %%
d=int(input("Enter the year of manufacturing: "))
# Out:
# Enter the year of manufacturing: 2003

# %%
e=int(input("Enter the Power of engine: "))
# Out:
# Enter the Power of engine: 800

# %%
f=int(input("Enter the Number of seat you want: "))
# Out:
# Enter the Number of seat you want: 4

# %%
g=int(input("Enter the Currency in 0 or 1 1 for lakh and 0 for crore: "))
# Out:
# Enter the Currency in 0 or 1 1 for lakh and 0 for crore: 0

# %%
h=int(input("Enter the type of vehicle 0 for automatic and 1 for manual: "))
# Out:
# Enter the type of vehicle 0 for automatic and 1 for manual: 1

# %%
model.predict([[c,d,e,f,g,h]])
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([11342551.25276157])
